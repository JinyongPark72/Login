# %% [markdown]
# <a href="https://colab.research.google.com/github/JinyongPark72/Login/blob/master/Drive_CB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai-whisper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 33.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.3 MB/s eta 0:00:00
# ...
#   Created wheel for openai-whisper: filename=openai_whisper-20250625-py3-none-any.whl size=803979 sha256=a3b57f352099965a34e5c0a38b26d2c58694d11f886a4f1a7b8fec7721da6af4
#   Stored in directory: /root/.cache/pip/wheels/61/d2/20/09ec9bef734d126cba375b15898010b6cc28578d8afdde5869
# Successfully built openai-whisper
# ...

# %%
import whisper
import re

# 1. 음성 → 텍스트
def speech_to_text(audio_file):
    model = whisper.load_model("small")  # 처음은 base 추천
    result = model.transcribe(audio_file, language='ko')
    return result["text"]

# 2. 텍스트 → 출발/도착 추출 (1차: 규칙 기반)
def clean_location(text):
    # 자주 붙는 조사 제거
    particles = ["에서", "에", "로", "으로"]
    for p in particles:
        if text.endswith(p):
            text = text[:-len(p)]
    return text.strip()

def extract_locations(text):
    match = re.search(r"(.+?)에서 (.+)", text)
    if match:
        start = clean_location(match.group(1))
        end = clean_location(match.group(2))
        return start, end

    parts = text.split()
    if len(parts) >= 2:
        start = clean_location(parts[0])
        end = clean_location(parts[-1])
        return start, end

    return None, None

# 3. 실행
if __name__ == "__main__":
    audio_file = "test.m4a"  # 여기에 음성 파일 넣기

    text = speech_to_text(audio_file)
    print(f"인식된 문장: {text}")

    start, end = extract_locations(text)

    if start and end:
        print(f"출발지: {start}")
        print(f"도착지: {end}")
    else:
        print("❌ 위치 추출 실패 (다시 말해 주세요)")
# Out:
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 인식된 문장:  강남에 서 잠실
# 출발지: 강남
# 도착지: 잠실
